# %% [markdown]
# <a href="https://colab.research.google.com/github/jessica-guan/Python-DataSci-ML/blob/main/Neural%20Networks%20in%20keras.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Homework 16: Introduction to Neural Networks in keras**
# ---
#
# ### **Description**
# This homework assignment will focus on building, visualizing, and training neural networks using the keras Python library. This will cover key topics including building neural networks by layer (sequential models) and visualizing neural networks.
#
# <br>
#
# ### **Structure**
# **Part 1**: [Building and Visualizing a Neural Network](#p1)
#  >    **Part 1.1**: [Simple Neural Networks](#p1.1)
#
#  >    **Part 1.2**: [Adding Activation Functions](#p1.2)
#
#
#
# <br>
#
# ### **Learning Objectives**
#
# * Recognize the basic components of deep learning with keras.
#
# * Recognize how to build a basic sequential model.
#
# <br>
#
#
# ### **Resources**
# * [Deep Learning with keras](https://docs.google.com/document/d/1WCV2ok7dwPWCid5vdOImknCAJS2te5aQ8yRp6J5Clac/edit?usp=drive_link)
#
# <br>
#
# **Before starting, run the code below to import all necessary functions and libraries.**

# %%
# !pip install --quiet keras_visualizer
from keras.models import Sequential
from keras.layers import Dense, Input

from keras_visualizer import visualizer
from IPython.display import Image

from sklearn.datasets import load_diabetes
from sklearn.model_selection import train_test_split
from keras.optimizers import *
from keras.metrics import *

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# <a name="p1"></a>
#
# ---
# ## **Part #1: Building and Visualizing a Neural Network**
# ---
#
# As a reminder, these are the steps for building and training a neural network.
#
# 1. Import and split the data into a train/test set
# 2. Determine the dimensions of the data
# 3. Initialize the Network Model
# 4. Add an Input layer to the model
# 5. Add the hidden Layers to the model
# 6. Add the output layer
# 7. Fit the model
# 8. Evaluate the model

# %% [markdown]
# <a name="p1.1"></a>
#
# ### **Part #1.1: Simple Neural Networks**
# ---

# %% [markdown]
# ####**Problem 1.1.1**
#
# Initialize a neural network using `Sequential()` in keras. Add the following layers to the network.
#
# * An input layer with an input size of 10.
# * Two hidden layers with the following specifications:
#  * The first hidden layer should have 12 neurons.
#  * The second hidden layer should have 8 neurons.
# * Lastly, add an output layer that has 2 output nodes.
#
# This network can be used for multi-class classification tasks or other suitable applications.

# %%
model = Sequential()
model.add(Dense(units=12, input_shape=(10,), activation='relu'))
model.add(Dense(units=12, activation='relu'))
model.add(Dense(units=8, activation='relu'))
model.add(Dense(units=2, activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 12)                132
#
#  dense_1 (Dense)             (None, 12)                156
#
#  dense_2 (Dense)             (None, 8)                 104
#
#  dense_3 (Dense)             (None, 2)                 18
#
# ...
# Total params: 410 (1.60 KB)
# Trainable params: 410 (1.60 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# #### **Problem #1.1.2**
#
# Confirm we've made our model correctly using the `visualizer` function.

# %%
from tensorflow.keras.utils import plot_model
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %% [markdown]
# ####**Problem 1.1.3**
#
# Initialize a neural network using `Sequential()` in keras. Add the following layers to the network.
#
# * An input layer with an input size of 6.
# * Two hidden layers with the following specifications:
#  * The first hidden layer should have 15 neurons.
#  * The second hidden layer should have 10 neurons.
# * Lastly, add an output layer that has 3 output nodes.
#
# This type of network might be used for tasks like multi-class classification for three classes.
#
# Finally, visualize the model using the `visualizer` function.

# %%
model = Sequential()
model.add(Dense(units=15, input_shape=(6,), activation='relu'))
model.add(Dense(units=15, activation='relu'))
model.add(Dense(units=10, activation='relu'))
model.add(Dense(units=3, activation='softmax'))
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %% [markdown]
# <a name="p1.2"></a>
#
# ### **Part #1.2: Adding Activation Functions**
# ---

# %% [markdown]
# ####**Problem 1.2.1**
#
# Create and visualize a neural network model with the following specifications using keras:
#
# * An input layer with 3 neurons.
# * A single hidden layer with 7 neurons, using the "ReLU" activation function.
# * An output layer with 2 neurons, followed by the "ReLU" activation function.

# %%
model = Sequential()
model.add(Dense(units=7, input_shape=(3,), activation='relu'))
model.add(Dense(units=7, activation='relu'))
model.add(Dense(units=2, activation='relu'))
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %% [markdown]
# ####**Problem 1.2.2**
#
# Create and visualize a neural network model with the following specifications using keras:
#
# * An input layer with 6 neurons.
# * Two hidden layers:
#  * The first hidden layer with 8 neurons, using the "Sigmoid" activation function.
#  * The second hidden layer with 5 neurons, using the "Tanh" activation function.
# * An output layer with 4 neurons, followed by the "ReLU" activation function.

# %%
model = Sequential()
model.add(Dense(units=8, input_shape=(6,), activation='sigmoid'))
model.add(Dense(units=8, activation='sigmoid'))
model.add(Dense(units=5, activation='tanh'))
model.add(Dense(units=4, activation='relu'))
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %% [markdown]
# #End of notebook
# ---
# © 2024 The Coding School, All rights reserved
